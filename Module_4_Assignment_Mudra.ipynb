# %%
# What is File function in python? What is keywords to create and write file.

Files are used to permanently store data. To create and write a file we use open and .write() method.

# %%
# Write a Python program to read an entire text file.

def file_read(fname):
        txt = open(fname)
        print(txt.read())

file_read('test.txt')

# %%
# Write a Python program to append text to a file and display the text.

def file_read(fname):
        from itertools import islice
        with open(fname, "w") as myfile:
                myfile.write("Python \n")
                myfile.write("Java ")
        txt = open(fname)
        print(txt.read())
file_read('abc.txt')

# %%
# Write a Python program to read first n lines of a file.

def file(fname, nlines):
        from itertools import islice
        with open(fname) as f :
                for line in islice(f, nlines):
                        print(line)
file('test.txt',2)

# %%
# Write a Python program to read last n lines of a file.

a_file = open("example.txt", "r")
lines = a_file. readlines()
last_lines = lines[-5:]
print(last_lines)
a_file. close()

# %%
# Write a Python program to read a file line by line and store it into a list

def file_read(fname):
        with open(fname) as f:
                #Content_list is the list that contains the read lines.     
                content_list = f.readlines()
                print(content_list)

file_read('test.txt')

# %%
# Write a Python program to read a file line by line store it into a variable.

def file_read(fname):
        with open (fname, "r") as myfile:
                data=myfile.readlines()
                print(data)
file_read('test.txt')

# %%
# Write a python program to find the longest words.

def longest_word(filename):
    with open(filename, 'r') as infile:
              words = infile.read().split()
    max_len = len(max(words, key=len))
    return [word for word in words if len(word) == max_len]

print(longest_word('test.txt'))

# %%
# Write a Python program to count the number of lines in a text file.

def file_len(fname):
        with open(fname) as f:
                for i, l in enumerate(f):
                        pass
        return i + 1
print("Number of lines in the file :",file_len("test.txt"))

# %%
# Write a Python program to count the frequency of words in a file.

from collections import Counter
def word_count(fname):
        with open(fname) as f:
                return Counter(f.read().split())

print("Number of words in the file :",word_count("test.txt"))

# %%
# Write a Python program to write a list to a file.

elements = ['Air', 'Sky', 'Earth', 'Fire', 'water']
with open('abc.txt', "w") as myfile:
        for i in elements:
                myfile.write("%s\n" % i)

content = open('abc.txt')
print(content.read())

# %%
# Write a Python program to copy the contents of a file to another file.

oFile = input(print("Enter the first file name : "))
sFile = input(print("Enter the second file name : "))

fileHandle = open(oFile, "r")
texts = fileHandle.readlines()
fileHandle.close()

fileHandle = open(sFile, "w")
for s in texts:
    fileHandle.write(s)
fileHandle.close()

print("\nFile Copied Successfully!")

# %%
# Explain Exception handling? What is an Error in Python?

Exception is occured during execution of program
Error generates during compilation of program.
Error are caused by system.

# %%
# How many except statements can a try-except block have? Name Some built-in exception classes:

There has to be more than one except statements in try-except block. 
The built-in exceptions classes are: KeyError , NameError ,SyntaxError , TypeError.

# %%
# When will the else part of try-except-else be executed?

The else part of try-except-else be executed when no exception occurs.

# %%
# Can one block of except statements handle multiple exception?

Try-except blocks can be used to catch and respond to one or multiple exceptions.

# %%
# When is the finally block executed?

Finally block is always executed after leaving the try statement.

# %%
# What happens when „1‟== 1 is executed?

When „1‟== 1 is executed, it simply evaluates to false and does not raise any exception.

# %%
# How Do You Handle Exceptions With Try/Except/Finally In Python? Explain with coding snippets.

try:
  print('statement')
except:
  print('something went wrong.')
finally:
  print('always executing')

# %%
# Write python program that user to enter only odd numbers, else will raise an exception.

a = int(input("Enter numerator number: "))
x = a % 2
try:
  if x > 0:
    print( 'The number ypu have enter is odd.')
  else:
    print("It's an Even Number")
except ValueError:
      pass
finally:
    print("Done...!")

# %%
# What are oops concepts? Is multiple inheritance supported in java.

Object oriented programming is a technique or style which is associated with an object and a class.

# %%
# How to Define a Class in Python? What Is Self? Give An Example Of A Python Class.

A class in Python can be defined using the class keyword. 
Self represents the instance of the class.

class Person:
    print('This is a person class')
    
    def greet(self):
        print('Hello')

# %%
# Write a Python class named Rectangle constructed by a length and width and a method which will compute the area of a rectangle.

class Rectangle():
    def __init__(self, l, w):
        self.length = l
        self.width  = w

    def rectangle_area(self):
        return self.length*self.width

obj = Rectangle(12, 10)
print(obj.rectangle_area())

# %%
# Write a Python class named Circle constructed by a radius and two methods which will compute the area and the perimeter of a circle.

class Circle():
  
  def radius(self,radius):
      r = radius
  def area(self,r):
      area = 3.142*r*r
      print("Area of the circle is: ",area)
  def peri(self,r):
      peri = 2*3.14*r
      print("Perimeter of the circle is: ",peri)

c = Circle()
radius = int(input("Enter the radius of circle: "))
c.area(radius)
c.peri(radius)

# %%
# Explain Inheritance in Python with an example? What is init? Or What Is A Constructor In Python?

Inheritance allow's to transmit data members from one class to another class.
init is reserved method in python classes known as constructor. It is called when object created.

class Country:

     def ShowCountry(self):
         print('This is Spain')
class State(Country):
     def ShowState(self):
         print('This is State')

st =State()
st.ShowCountry()
st.ShowState()

# %%
# What is Instantiation in terms of OOP terminology?

Instantiation describes the processes of creating a new object for a class using a new keyword.

# %%
# What is used to check whether an object o is an instance of class A?

isinstance(o , A) function is used to check whether an object o is an instance of class A.

# %%
# What relationship is appropriate for Course and Faculty?

Association

# %%
# What relationship is appropriate for Student and Person?

Inheritance
