# %% [markdown]
# **1 -** Why Django should be used for web-development? Explain how you can
# create a project in Django?

# %% [markdown]
# **Ans -**Django is a high-level Python web framework that enables rapid development of secure and maintainable websites.

# %% [markdown]
# **Ans -**1. django-admin startproject project_name .
# 2. django-admin startapp app_name
# 3. python manage.py makemigrations - collect custom models/db tables schema
# 4. python manage.py migrate - apply all migrations to database.
# 5. python manage.py createsuperuser - username, email, password, re-password
# 6. python manage.py runserver - default IP 127.0.0 1:8000/localhost:8000
# 7. CTRL+C - break/close the server

# %% [markdown]
# **2 -** How to check installed version of django?

# %% [markdown]
# **Ans -**Using the django-admin command line (terminal commands) $ django-admin version.

# %% [markdown]
# **3 -** Mention what command line can be used to load data into Django?

# %% [markdown]
# **Ans -**To load data into Django > Django-admin.py loaddata command line is used.

# %% [markdown]
# **4 -** Explain what does django-admin.py make messages command is used
# for?

# %% [markdown]
# **Ans -** It creates (or updates) a message file in the conf/locale (in the Django tree) or locale (for project and application) directory.

# %% [markdown]
# **5 -** What is .Django URLs?

# %% [markdown]
# **Ans -** In Django, views are Python functions which take a URL request as parameter and return an HTTP response or throw an exception.

# %% [markdown]
# **6 -** What is a QuerySet?Write program to create a new Post object in
# database:

# %% [markdown]
# **Ans -** A QuerySet is a collection of data from a database.

# %%
from django.conf import settings
from django.db import models
from django.utils import timezone


class Post(models.Model):
    author = models.ForeignKey(settings.AUTH_USER_MODEL, on_delete=models.CASCADE)
    title = models.CharField(max_length=200)
    text = models.TextField()
    created_date = models.DateTimeField(default=timezone.now)
    published_date = models.DateTimeField(blank=True, null=True)

    def publish(self):
        self.published_date = timezone.now()
        self.save()

    def __str__(self):
        return self.title
