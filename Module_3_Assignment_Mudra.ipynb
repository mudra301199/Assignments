# %%
# What is List? How will you reverse a list?

Lists are used to store multiple items in a single variable. 
Lists are one of 4 built-in data types in Python used to store collections of data, the other 3 are Tuple, Set, 
and Dictionary, all with different qualities and usage.

Reversing a List In-Place With the list. reverse() Method.
# Out:
#   File "<ipython-input-1-a4f3bc381a77>", line 3
#     Lists are used to store multiple items in a single variable.
#             ^
# SyntaxError: invalid syntax

# %%
# How will you remove last object from a list?

pop() You can use list. pop() method to remove the last element from the list. pop will raise index error if the list is empty.
# Out:
#   File "<ipython-input-2-4d70c8ff55d4>", line 3
#     pop() You can use list. pop() method to remove the last element from the list. pop will raise index error if the list is empty.
#             ^
# SyntaxError: invalid syntax

# %%
# Suppose list1 is [2, 33, 222, 14, and 25], what is list1 [-1]?

[-1] is the last index of the list
# Out:
#   File "<ipython-input-3-977b9b40fadd>", line 3
#     [-1] is the last index of the list
#                    ^
# SyntaxError: invalid syntax

# %%
# Differentiate between append () and extend () methods?

The append() function can add a single element to the end of a list.	
The extend() function can add multiple elements from a list supplied to it as argument.

# %%
# Write a Python function to get the largest number,smallest num and sum of all from a list.

list1 = [10, 20, 4, 45, 99]
list1.sort()
print("Smallest element is:", *list1[:1])
print("Largest element is:", list1[-1])
total = sum(list1)
print("Sum of all elements in given list: ", total)
# Out:
# Smallest element is: 4
# Largest element is: 99
# Sum of all elements in given list:  178

# %%
# How will you compare two lists?

by using not equal to
by using if condition

# %%
# Write a Python program to count the number of strings where the string length is 2 or more and the first and last character are same from a given list of strings.

def match_words(words):
  ctr = 0

  for word in words:
    if len(word) > 1 and word[0] == word[-1]:
      ctr += 1
  return ctr

print(match_words(['abba', '1234', 'aa', '3223']))
# Out:
# 3

# %%
# Write a Python program to remove duplicates from a list.

my_list = [1,1,2,3,2,2,4,5,6,2,1]
my_final_list = set(my_list)
print(list(my_final_list))
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# Write a Python program to check a list is empty or not.

list1 = [1,2,3,4,5]

if not list1:
    print("The List is Empty")
else:
    print("The List is Not Empty")
# Out:
# The List is Not Empty

# %%
# Write a Python function that takes two lists and returns true if they have at least one common member.

def common_data(list1, list2):
     result = False
     for x in list1:
         for y in list2:
             if x == y:
                 result = True
                 return result
print(common_data([1,2,3,4,5], [5,6,7,8,9]))
print(common_data(['m','i','u'], ['s','y','e']))
# Out:
# True
# True

# %%
# Write a Python program to generate and print a list of first and last 5 elements where the values are square of numbers between 1 and 30.

def printValues():
	l = list()
	for i in range(1,6):
		l.append(i**2)
	print(l[:5])

printValues()
# Out:
# [1, 4, 9, 16, 25]

# %%
# Write a Python function that takes a list and returns a new list with unique elements of the first list.

def f(l):
    x = []
    for a in l:
        if a not in x:
            x.append(a)
    return x

print(f([1,2,3,4,4,4,5]))
# Out:
# [1, 2, 3, 4, 5]

# %%
# Write a Python program to convert a list of characters into a string.

list1 = ['M', 'u', 'd', 'r', 'a']
print("list1: ", list1)
print("type(list1): ", type(list1))
print()
str1 = ""
for i in list1:
  str1 += i;
print("str1: ", str1)
print("type(str1): ", type(str1))
# Out:
# list1:  ['M', 'u', 'd', 'r', 'a']
# type(list1):  <class 'list'>
#
# str1:  Mudra
# type(str1):  <class 'str'>

# %%
# Write a Python program to select an item randomly from a list.

Student = ['Mudra', 'Hritika', 'Nirali', 'Himal', 'Meghdeep']
print(random.choice(Student))
# Out:
# Meghdeep

# %%
# Write a Python program to find the second smallest number in a list.

li = [5,9,1,2,8,4] 
li.sort() 
print("The sorted list: ", li) 
print("The second smallest value of this list: ",li[1])
# Out:
# The sorted list:  [1, 2, 4, 5, 8, 9]
# The second smallest value of this list:  2

# %%
# Write a Python program to get unique values from a list.

l = [10,20,30,10,50,60]
print("ol:",l)
ms = set(l)
mnl = list(ms)
print("loun:",mnl)
# Out:
# ol: [10, 20, 30, 10, 50, 60]
# loun: [10, 50, 20, 60, 30]

# %%
# Write a Python program to check whether a list contains a sub list.

# %%
# Write a Python program to split a list into different variables.

# %%
# What is tuple? Difference between list and tuple.

tuples are used to store multiple items in a single variable.

difference
list are enclosed by [] whereas tuples are enclosed by ()
data entered in a list can be changed whereas the data entered in a tuple cannot be changed

# %%
# Write a Python program to create a tuple with different data types.

# %%
# Write a Python program to create a tuple with numbers.

intTuple = ()
number = int(input("Please enter the Total Tuple Items to store = "))
for i in range(1, number + 1):
    value = int(input("Please enter %d Tuple Item = " %i))
    intTuple += (value,)

print("Tuple Items = ", intTuple)
# Out:
# Please enter the Total Tuple Items to store = 3
# Please enter 1 Tuple Item = 10
# Please enter 2 Tuple Item = 20
# Please enter 3 Tuple Item = 30
# Tuple Items =  (10, 20, 30)

# %%
# Write a Python program to convert a tuple to a string.

tuple=('P','y','t','h','o','n') 
str=''.join(tuple)
print('string is:', str)
# Out:
# string is: Python

# %%
# Write a Python program to check whether an element exists within a tuple.

t = ("m", "u", "d", "r", "a", "p", "a", "t", "e", "l")
print("v" in t)
# Out:
# False

# %%
# Write a Python program to find the length of a tuple.

t = tuple("Mudra")
print(t)
print(len(t))
# Out:
# ('M', 'u', 'd', 'r', 'a')
# 5

# %%
# Write a Python program to convert a list to a tuple.

l = [1, 2, 3, 4, 5, 6]
print(l)
t = tuple(l)
print(t)
# Out:
# [1, 2, 3, 4, 5, 6]
# (1, 2, 3, 4, 5, 6)

# %%
# Write a Python program to reverse a tuple.

x = (3 , 2 , 1)
y = ('Hritika', 'Nirali', 'Mudra')
result = reversed(x)
result_1 = reversed(y)
result = tuple(result)
result_1 = tuple(result_1)
print(result)
print(result_1)
# Out:
# (1, 2, 3)
# ('Mudra', 'Nirali', 'Hritika')

# %%
# Write a Python program to replace last value of tuples in a list.

# %%
# Write a Python program to find the repeated items of a tuple.
# Out:
# Enter any value:10 20 30 40 10
# Repeated Values:
# 10

# %%
# Write a Python program to remove an empty tuple(s) from a list of tuples.

def Remove(tuples):
    tuples = [t for t in tuples if t]
    return tuples
tuples = [(), ('ram','15','8'), (), ('laxman', 'sita'), 
          ('krishna', 'akbar', '45'), ('',''),()]
print(Remove(tuples))
# Out:
# [('ram', '15', '8'), ('laxman', 'sita'), ('krishna', 'akbar', '45'), ('', '')]

# %%
# Write a Python program to unzip a list of tuples into individual lists.

# %%
# Write a Python program to convert a list of tuples into a dictionary.

print (dict([('Mudra', 22), ('Hritika', 23), ('Nirali', 24)]))
# Out:
# {'Mudra': 22, 'Hritika': 23, 'Nirali': 24}

# %%
# How will you create a dictionary using tuples in python?

Using Dict keyword

# %%
# Write a Python script to sort (ascending and descending) a dictionary by value.

import operator
d = {1: 2, 3: 4, 4: 3, 2: 1, 0: 0}
print('Original dictionary : ',d)
sorted_d = sorted(d.items(), key=operator.itemgetter(1))
print('Dictionary in ascending order : ',sorted_d)
sorted_d = dict( sorted(d.items(), key=operator.itemgetter(1),reverse=True))
print('Dictionary in descending order : ',sorted_d)
# Out:
# Original dictionary :  {1: 2, 3: 4, 4: 3, 2: 1, 0: 0}
# Dictionary in ascending order :  [(0, 0), (2, 1), (1, 2), (4, 3), (3, 4)]
# Dictionary in descending order :  {3: 4, 4: 3, 1: 2, 2: 1, 0: 0}

# %%
# Write a Python script to concatenate following dictionaries to create a new one.

dic1={1:10, 2:20}
dic2={3:30, 4:40}
dic3={5:50,6:60}
dic4 = {}
for d in (dic1, dic2, dic3): dic4.update(d)
print(dic4)
# Out:
# {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

# %%
# Write a Python script to check if a given key already exists in a dictionary.

d = {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}
def is_key_present(x):
  if x in d:
      print('Key is present in the dictionary')
  else:
      print('Key is not present in the dictionary')
is_key_present(5)
is_key_present(9)
# Out:
# Key is present in the dictionary
# Key is not present in the dictionary

# %%
# How Do You Traverse Through A Dictionary Object In Python?

There are two ways of iterating through a Python dictionary object. 
One is to fetch associated value for each key in keys() list.

# %%
#  How Do You Check The Presence Of A Key In A Dictionary?

Using has_key() method returns true if a given key is available in the dictionary, otherwise, it returns a false.

# %%
# Write a Python script to print a dictionary where the keys are numbers between 1 and 15.

d=dict()
for x in range(1,16):
    d[x]=x**2
print(d)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144, 13: 169, 14: 196, 15: 225}

# %%
# Write a Python program to check multiple keys exists in a dictionary

student = {
  'name': 'Mudra',
  'class': 'VI',
  'roll_id': '1'
}
print(student.keys() >= {'class', 'name'})
print(student.keys() >= {'name', 'Mudra'})
print(student.keys() >= {'roll_id', 'name'})
# Out:
# True
# False
# True

# %%
# Write a Python script to merge two Python dictionaries

d1 = {'a': 100, 'b': 200}
d2 = {'x': 300, 'y': 200}
d = d1.copy()
d.update(d2)
print(d)
# Out:
# {'a': 100, 'b': 200, 'x': 300, 'y': 200}

# %%
# Write a Python program to map two lists into a dictionary

# %%
# Write a Python program to combine two dictionary adding values for common keys. d1 = {'a': 100, 'b': 200, 'c':300} d2 = {'a': 300, 'b': 200,’d’:400}

from collections import Counter
d1 = {'a': 100, 'b': 200, 'c':300}
d2 = {'a': 300, 'b': 200, 'd':400}
d = Counter(d1) + Counter(d2)
print(d)
# Out:
# Counter({'a': 400, 'b': 400, 'd': 400, 'c': 300})

# %%
# Write a Python program to print all unique values in a dictionary.

L = [{"V":"S001"}, {"V": "S002"}, {"VI": "S001"}, {"VI": "S005"}, {"VII":"S005"}, {"V":"S009"},{"VIII":"S007"}]
print("Original List: ",L)
u_value = set( val for dic in L for val in dic.values())
print("Unique Values: ",u_value)
# Out:
# Original List:  [{'V': 'S001'}, {'V': 'S002'}, {'VI': 'S001'}, {'VI': 'S005'}, {'VII': 'S005'}, {'V': 'S009'}, {'VIII': 'S007'}]
# Unique Values:  {'S009', 'S002', 'S005', 'S007', 'S001'}

# %%
# Why Do You Use the Zip () Method in Python?

# %%
# Write a Python program to create and display all combinations of letters, selecting each letter from a different key in a dictionary. Sample data: {'1': ['a','b'], '2': ['c','d']} Expected Output: o ac ad bc bd

import itertools      
d ={'1':['a','b'], '2':['c','d']}
for combo in itertools.product(*[d[k] for k in sorted(d.keys())]):
    print(''.join(combo))
# Out:
# ac
# ad
# bc
# bd

# %%
# Write a Python program to find the highest 3 values in a dictionary

from collections import Counter

my_dict = {'A': 67, 'B': 23, 'C': 45,
           'D': 56, 'E': 12, 'F': 69}
k = Counter(my_dict)
high = k.most_common(3)
print("Initial Dictionary:")
print(my_dict, "\n")
print("Dictionary with 3 highest values:")
print("Keys: Values")
for i in high:
    print(i[0]," :",i[1]," ")
# Out:
# Initial Dictionary:
# {'A': 67, 'B': 23, 'C': 45, 'D': 56, 'E': 12, 'F': 69}
#
# Dictionary with 3 highest values:
# Keys: Values
# F  : 69
# A  : 67
# D  : 56

# %%
# Write a Python program to combine values in python list of dictionaries.Sample data: [{'item': 'item1', 'amount': 400}, {'item': 'item2', 'amount': 300}, {'item': 'item1', 'amount': 750}]Expected Output: Counter ({'item1': 1150, 'item2': 300})

from collections import Counter
item_list = [{'item': 'item1', 'amount': 400}, {'item': 'item2', 'amount': 300}, {'item': 'item1', 'amount': 750}]
result = Counter()
for d in item_list:
    result[d['item']] += d['amount']
print(result)
# Out:
# Counter({'item1': 1150, 'item2': 300})

# %%
# Write a Python program to create a dictionary from a string.o Note: Track the count of the letters from the string. Sample string:'w3resource' Expected output: {'3': 1,’s’: 1, 'r': 2, 'u': 1, 'w': 1, 'c': 1, 'e': 2, 'o': 1}

from collections import defaultdict, Counter
str1 = 'w3resource' 
my_dict = {}
for letter in str1:
    my_dict[letter] = my_dict.get(letter, 0) + 1
print(my_dict)
# Out:
# {'w': 1, '3': 1, 'r': 2, 'e': 2, 's': 1, 'o': 1, 'u': 1, 'c': 1}

# %%
# Write a Python function to calculate the factorial of a number (a nonnegative integer)

def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n-1)
n=int(input("Input a number to compute the factiorial : "))
print(factorial(n))
# Out:
# Input a number to compute the factiorial : 5
# 120

# %%
# Write a Python function to check whether a number is in a given range

def test_range(n):
    if n in range(3,9):
        print( " %s is in the range"%str(n))
    else :
        print("The number is outside the given range.")
test_range(5)
# Out:
#  5 is in the range

# %%
# Write a Python function to check whether a number is perfect or not.

def perfect_number(n):
    sum = 0
    for x in range(1, n):
        if n % x == 0:
            sum += x
    return sum == n
print(perfect_number(6))
# Out:
# True

# %%
# Write a Python function that checks whether a passed string is palindrome or not

def isPalindrome(string):
	left_pos = 0
	right_pos = len(string) - 1
	
	while right_pos >= left_pos:
		if not string[left_pos] == string[right_pos]:
			return False
		left_pos += 1
		right_pos -= 1
	return True
print(isPalindrome('mudra'))
# Out:
# False

# %%
# How do you perform pattern matching in Python? Explain

# %%
# What is lambda function in python? What we call a function which is incomplete version of a function?

A Lambda Function in Python programming is an anonymous function or a function having no name. 
It is a small and restricted function having no more than one line. 
Just like a normal function, a Lambda function can have multiple arguments with one expression.

# %%
# How Many Basic Types Of Functions Are Available In Python?

There are two basic types of functions: built-in functions and user defined functions. 
The built-in functions are part of the Python language; for instance dir , len , or abs . 
The user defined functions are functions created with the def keyword.

# %%
# How can you pick a random item from a list or tuple?

To get random elements from sequence objects such as lists, tuples, strings in Python, use choice() , sample() , choices() of the random module. 
choice() returns one random element, and sample() and choices() return a list of multiple random elements.

# %%
# How can you pick a random item from a range?

Use randrnage() to generate random integer within a range Use a random. 
Randrange() function to get a random integer number from the given exclusive range by specifying the increment.

# %%
# How can you get a random number in python?

To generate random number in Python, randint() function is used. This function is defined in random module.

# %%
# How will you set the starting value in generating random numbers?

The random number generator needs a number to start with (a seed value), to be able to generate a random number. 
By default the random number generator uses the current system time. 
Use the seed() method to customize the start number of the random number generator.

# %%
# How will you randomizes the items of a list in place?

The shuffle() method randomizes the items of a list in place.

# %%
# Write a Python program to read a random line from a file.

import random
def random_line(fname):
    lines = open(fname).read().splitlines()
    return random.choice(lines)
print(random_line('test.txt'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-99c0cb08a5d3> in <module>()
#       5     lines = open(fname).read().splitlines()
#       6     return random.choice(lines)
# ----> 7 print(random_line('test.txt'))
#
# <ipython-input-7-99c0cb08a5d3> in random_line(fname)
#       3 import random
#       4 def random_line(fname):
# ----> 5     lines = open(fname).read().splitlines()
#       6     return random.choice(lines)
#       7 print(random_line('test.txt'))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test.txt'

# %%
# Write a Python program to convert degree to radian

pi=22/7
degree = float(input("Input degrees: "))
radian = degree*(pi/180)
print(radian)
# Out:
# Input degrees: 26
# 0.45396825396825397

# %%
# Write a Python program to calculate the area of a trapezoid

base_1 = 5
base_2 = 6
height = float(input("Height of trapezoid: "))
base_1 = float(input('Base one value: '))
base_2 = float(input('Base two value: '))
area = ((base_1 + base_2) / 2) * height
print("Area is:", area)
# Out:
# Height of trapezoid: 10
# Base one value: 5
# Base two value: 5
# Area is: 50.0

# %%
# Write a Python program to calculate the area of a parallelogram

base = float(input('Length of base: '))
height = float(input('Measurement of height: '))
area = base * height
print("Area is: ", area)
# Out:
# Length of base: 10
# Measurement of height: 5
# Area is:  50.0

# %%
# Write a Python program to calculate surface volume and area of a cylinder

pi=22/7
height = float(input('Height of cylinder: '))
radian = float(input('Radius of cylinder: '))
volume = pi * radian * radian * height
sur_area = ((2*pi*radian) * height) + ((pi*radian**2)*2)
print("Volume is: ", volume)
print("Surface Area is: ", sur_area)
# Out:
# Height of cylinder: 5
# Radius of cylinder: 4
# Volume is:  251.42857142857142
# Surface Area is:  226.28571428571428

# %%
# Write a Python program to returns sum of all divisors of a number

def sum_div(number):
    divisors = [1]
    for i in range(2, number):
        if (number % i)==0:
            divisors.append(i)
    return sum(divisors)
print(sum_div(10))
print(sum_div(12))
# Out:
# 8
# 16

# %%
# Write a Python program to find the maximum and minimum numbers from the specified decimal numbers.

from decimal import *
data = list(map(Decimal, '2.45 2.69 2.45 3.45 2.00 0.04 7.25'.split()))
print("Maximum: ", max(data))
print("Minimum: ", min(data))
# Out:
# Maximum:  7.25
# Minimum:  0.04
